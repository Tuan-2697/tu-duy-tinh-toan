# %%
#W2A1
print('Hello World')
# Out:
# Hello World

# %%
#W2A2
name = input("Nhap ten cua ban: ")
print(f"Hello, {name}!")
# Out:
# Hello, Tuan!

# %%
#W2A3
a = int(input("Nhap so a: "))
b = int(input("Nhap so b: "))

print(f"Tong cua {a} va {b} la: {a} + {b} = {a+b}")
print(f"Hieu cua {a} va {b} la: {a} - {b} = {a-b}")
print(f"Tich cua {a} va {b} la: {a * b}")
print(f"Phan nguyen cua {a} va {b} la: {a//b}")
print(f"Phan du cua {a} va {b} la: {a % b}")
print(f"Ket qua chia thuc cua {a} va {b} la: {a/b}")
# Out:
# Tong cua 1 va 2 la: 1 + 2 = 3
# Hieu cua 1 va 2 la: 1 - 2 = -1
# Tich cua 1 va 2 la: 2
# Phan nguyen cua 1 va 2 la: 0
# Phan du cua 1 va 2 la: 1
# Ket qua chia thuc cua 1 va 2 la: 0.5

# %%
#W2A4
a1, b1, c1, a2, b2, a3 = map(int,input().split())
diemtrungbinh = ((a1 + b1 + c1) + (a2 + b2) * 2 + a3 * 3) / 10
print(f"{diemtrungbinh:.1f}")
# Out:
# 40.5

# %%
#W2A5
a, b = map(int, input().split())
s = a**b
print(s)
# Out:
# 8

# %%
#W2A6
ch = input()
maunicode = ord(ch)
inhoa = chr(ord(ch) - 32)
print(f"{maunicode} {inhoa}")
# Out:
# 116 T

# %%
#W2A7
A = ((13 ** 2) * 3) + 5
B = 13**2*3 + 5
print(f"{A}{B}")
# Out:
# 512
# 512

# %%
#W2A8
C = int(input())
F = 9/5*C + 32
print(f"{F:.2f}")
# Out:
# 212.00

# %% [markdown]
# [ShoppingOnline] #W2A9
# Sơn Tùng mua một chiếc đồng hồ Movado trên trang mua sắm trực tuyến Amazon. Chiếc
# đồng hồ có giá x USD (x nhập từ bàn phím). Bởi Amazon không vận chuyển trực tiếp về
# Việt Nam, Đạt phải trả 10 USD cho phí vận chuyển từ một nước trung gian. Khi vận chuyển
# về Việt Nam, Đạt được thông báo sẽ phải trả thêm 30% thuế xuất nhập cảnh và 10% thuế
# VAT cho chiếc đồng hồ nói trên. Viết chương trình tính tổng số tiền mà Đạt phải trả để mua
# được chiếc đồng hồ trên (USD). Kết quả làm tròn đến hai chữ số thập phân.

# %%
#W2A9
x = float(input())
tongtien = x + 10 + x*0.3 + x*0.1
print(f"Tong so tien Dat tra la: {tongtien} (USD)")
# Out:
# Tong so tien Dat tra la: 150.0 (USD)

# %% [markdown]
# [Friend Names]
# Viết chương trình nhập vào tên 3 người từ bàn phím.
# In ra màn hình tên theo thứ tự đảo ngược.
# VD: input ("Bob Alice Helen") thì output: ("Hi Helen, Alice and Bob.")

# %%
#W2A10
a, b, c = map(str, input().split())
print(f"Hi {c}, {b} and {a}.")
# Out:
# Hi Helen, Alice and Bob.

# %% [markdown]
# Viết chương trình chuyển từ giờ và phút sang giây
# Đầu vào gồm hai giá trị chứa số giờ \h và số phút \m:
# Đầu ra: In ra màn hình một dòng duy nhất số giờ và phút được chuyển sang đơn vị giây.

# %%
#W2A11
n = input()
h, m = map(int, n.split())
sogiay = a*3600 + b*60
print(sogiay)
# Out:
# 24000

# %% [markdown]
# Cho một khối Rubik có độ dài cạnh là n, hãy trả về số lượng miếng dán riêng lẻ cần thiết để
# bao phủ toàn bộ khối lập phương. Ví dụ, khối rubic có độ dài cạnh là 1 cần 6 miếng dán
# riêng lẻ. (Lưu ý: một khối rubic có 6 mặt)

# %%
n = int(input())
s = n**2*6
print(f"So mieng dan rieng le can thiet la: {s}")
# Out:
# So mieng dan rieng le can thiet la: 6

# %% [markdown]
#  Nhập vào từ bàn phím hai số nguyên dương \a và \b, viết chương trình trả về hàng đơn vị
# của phép tính tích giữa \a và \b.

# %%
a, b = map(int, input().split())
n = (a*b) % 10
print(n)
# Out:
# 0

# %% [markdown]
# Viết chương trình hoán đổi giá trị giữa hai số a và b mà không cần khai báo thêm một biến/
# hàm nào khác.

# %%
a, b = map(int, input().split())
print(f"{b} {a}")
# Out:
# 4 3

# %% [markdown]
# Viết chương trình nhận vào một số nguyên dương n và trả về "số sao" thứ n.
# Một "số sao" là một số hình học trung tâm đại diện cho một hình lục giác có tâm (ngôi sao
# sáu cánh), giống như hình dạng được sử dụng trong trò chơi cờ Trung Quốc.

# %%
n = int(input())

# %% [markdown]
# [SeasonsInYear]
# Trong bài tập này, bạn sẽ sử dụng hàm print để in nhiều dòng ra màn hình. Có nhiều cách để
# làm việc này, cách thứ nhất là sử dụng lệnh print nhiều lần để in nhiều dòng khác nhau. Ví
# dụ, để in ra tên 4 mùa bằng tiếng Anh trên 4 dòng, bạn dùng 4 lệnh như sau:
# print("Spring")
# print("Summer")
# print("Autumn")
# print("Winter")
# Trong cách thứ hai, bạn sử dụng duy nhất một lệnh print và đưa liên tiếp các dòng chữ trên
# ra như sau:
# print("Spring\nSummer\nAutumn\nWinter")
# Lưu ý rằng đây là một lệnh duy nhất, khi gặp dấu ‘\n’ là một kí tự xuống dòng được in ra.
# Ngoài ra, bạn hãy tự tìm hiểu xem có còn cách nào khác không.
# Để luyện tập, hãy viết vào ô dưới đây chương trình in ra trên màn hình tên các mùa trong
# năm bằng tiếng Anh. Mỗi mùa in trên một dòng, bắt đầu từ "Spring"

# %%
#W2A16
print("Spring\nSummer\nAutumn\nWinter")
# Out:
# Spring
# Summer
# Autumn
# Winter

# %% [markdown]
# [DrawTriangle]
# Sử dụng hàm print, bạn có thể in ra các dòng văn bản, các câu thông báo. Ngoài ra, với chút
# nghệ thuật xếp đặt (ký tự), bạn có thể vẽ nhiều hình vẽ đẹp và thú vị. Giới hạn chính là trí
# tưởng tượng của bạn.
# Trong bài này, bạn được yêu cầu viết chương trình vẽ ra một tam giác cân bằng các dấu sao
# trên 3 dòng. Hãy kết hợp việc sử dụng khoảng trắng với các dấu sao để in ra tam giác này.
# Ví dụ, đoạn mã để in 2 dòng đầu của tam giác:
# print("" * "")
# print("" *** "")
# Yêu cầu: In ra màn hình tam giác có 3 dòng như sau:
# *
# ***
# *****

# %%
print('*\n***\n*****')
# Out:
# *
# ***
# *****

# %% [markdown]
# [Banner]
# Viết chương trình in ra dòng chữ "TDTT" như sau:
# ### # # ### ###
# # # # # #
# # # # # #
# # # # # #
# # # # # #

# %%
print('###  # #   ### ###\n #   #  #   #  #\n #   #   #  #  #\n #   #  #   #  #\n #   # #    #  #')
# Out:
# ###  # #   ### ###
#  #   #  #   #  #
#  #   #   #  #  #
#  #   #  #   #  #
#  #   # #    #  #

# %% [markdown]
# [Days of the week]
# Viết chương trình in ra các ngày trong một tuần bằng tiếng Anh. Mỗi ngày in trên một dòng
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %%
print('Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday')
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday

# %% [markdown]
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
print('January\nFebruary\nMarch\nApril\nMay\nJune\nJuly\nAugust\nSeptember\nOctober\nNovember\nDecember')
# Out:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %% [markdown]
# [Ten Hello World]
# Viết chương trình in ra màn hình dòng chữ "Hello, world" 10 lần.
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world

# %%
print('Hello, world\nHello, world\nHello, world\nHello, world\nHello, world\nHello, world\nHello, world\nHello, world\nHello, world')
# Out:
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
# Hello, world
